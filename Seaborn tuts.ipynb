# %% [markdown]
# # Seaborn: in a gist

# %% [markdown]
# ## Important Libraries

# %%
from matplotlib import pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
# %matplotlib inline

# %% [markdown]
# ### Demo data

# %%
x = [10, 20, 30, 40]
y = [0, 15, 10, 25]

# %% [markdown]
# ### Simple Matplotlib visualization

# %%
plt.plot(x,y)

# %% [markdown]
# ### Setting Seaborn for visualization

# %%
sns.set()

# %% [markdown]
# ### Matplotlib visualization `set()` to Seaborn style

# %%
plt.plot(x,y)

# %% [markdown]
# ### Setting plot style & visualizing

# %%
sns.set_style("white")

# %%
plt.plot(x,y)

# %% [markdown]
# # Trying out different types of seaborn plot types and exploring their options

# %% [markdown]
# ## KDEplot

# %%
cars = sns.load_dataset("mpg")

# %%
cars.dropna(inplace=True)

# %%
sns.set_style("darkgrid")

# %%
sns.kdeplot(cars.horsepower)
# Out:
# <AxesSubplot:xlabel='horsepower', ylabel='Density'>

# %%
sns.kdeplot(cars.horsepower, shade=True)
# Out:
# <AxesSubplot:xlabel='horsepower', ylabel='Density'>

# %%
sns.kdeplot(cars.horsepower, bw_adjust=2)
# Out:
# <AxesSubplot:xlabel='horsepower', ylabel='Density'>

# %%
sns.kdeplot(cars.horsepower, cumulative=True)
# Out:
# <AxesSubplot:xlabel='horsepower', ylabel='Density'>

# %% [markdown]
# ### KDEplot: Bivariate

# %%
sns.kdeplot(x=cars.horsepower, y=cars.mpg)
# Out:
# <AxesSubplot:xlabel='horsepower', ylabel='mpg'>

# %%
sns.kdeplot(x=cars.horsepower, y=cars.mpg, n_levels=20)
# Out:
# <AxesSubplot:xlabel='horsepower', ylabel='mpg'>

# %%
sns.kdeplot(x=cars.horsepower, y=cars.mpg, shade=True, thresh=0.05 ,cbar=True)
# Out:
# <AxesSubplot:xlabel='horsepower', ylabel='mpg'>

# %% [markdown]
# ## Histplot

# %%
sns.__version__
# Out:
# '0.11.2'

# %%
penguins = sns.load_dataset("penguins")
penguins
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
sns.set_style('whitegrid')

# %%
sns.histplot(x='bill_length_mm', data=penguins, kde=False, bins=20)
# Out:
# <AxesSubplot:xlabel='bill_length_mm', ylabel='Count'>

# %%
sns.histplot(x='bill_length_mm', data=penguins, kde=False, bins=[30,42,45,50,60])
# Out:
# <AxesSubplot:xlabel='bill_length_mm', ylabel='Count'>

# %%
sns.histplot(x='bill_length_mm', data=penguins, kde=False, binwidth=10, binrange=(30, 60))
# Out:
# <AxesSubplot:xlabel='bill_length_mm', ylabel='Count'>

# %%
sns.histplot(x='bill_length_mm', data=penguins, stat='density')
# Out:
# <AxesSubplot:xlabel='bill_length_mm', ylabel='Density'>

# %%
sns.histplot(x='bill_length_mm', data=penguins, stat='probability')
# Out:
# <AxesSubplot:xlabel='bill_length_mm', ylabel='Probability'>

# %%
sns.histplot(x='bill_length_mm', data=penguins, stat='probability', fill=False, element='step')
# Out:
# <AxesSubplot:xlabel='bill_length_mm', ylabel='Probability'>

# %%
sns.histplot(x='bill_length_mm', data=penguins, stat='probability', fill=False, element='step', cumulative=True)
# Out:
# <AxesSubplot:xlabel='bill_length_mm', ylabel='Probability'>

# %%
sns.histplot(x='bill_length_mm', data=penguins, hue='species', element='step', multiple='fill')
# Out:
# <AxesSubplot:xlabel='bill_length_mm', ylabel='Count'>

# %% [markdown]
# ### Histplot: Bivariate

# %%
sns.set_style('white')

# %%
sns.histplot(x='bill_length_mm', y='bill_depth_mm',data=penguins, hue='species', cbar=False)
# Out:
# <AxesSubplot:xlabel='bill_length_mm', ylabel='bill_depth_mm'>

# %%
sns.histplot(x='bill_length_mm', y='species',data=penguins, hue='species', cbar=False)
# Out:
# <AxesSubplot:xlabel='bill_length_mm', ylabel='species'>

# %%
sns.histplot(x='species', hue='sex', multiple='dodge', data=penguins)
# Out:
# <AxesSubplot:xlabel='species', ylabel='Count'>

# %%
sns.histplot(x='species', hue='sex', multiple='dodge', data=penguins, 
            shrink=0.8)
# Out:
# <AxesSubplot:xlabel='species', ylabel='Count'>

# %%
sns.histplot(x='bill_length_mm', data=penguins, color='indigo')
# Out:
# <AxesSubplot:xlabel='bill_length_mm', ylabel='Count'>

# %%
sns.histplot(x='bill_length_mm', data=penguins, color='indigo', fill=False)
# Out:
# <AxesSubplot:xlabel='bill_length_mm', ylabel='Count'>

# %%
sns.histplot(x='species', hue='sex', multiple='dodge', data=penguins, 
            shrink=0.8, palette='turbo')
# Out:
# <AxesSubplot:xlabel='species', ylabel='Count'>

# %% [markdown]
# ## ECDFplot (Emipircal Cumulative Distribution Function)

# %%
tips = sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.set_style('darkgrid')

# %%
sns.ecdfplot(x='tip', data=tips)
# Out:
# <AxesSubplot:xlabel='tip', ylabel='Proportion'>

# %%
tips.tip.value_counts().head()
# Out:
# 2.0    33
# 3.0    23
# 4.0    12
# 5.0    10
# 2.5    10
# Name: tip, dtype: int64

# %%
sns.ecdfplot(x='tip', data=tips)
plt.axvline(4, c="black")

# %%
sns.ecdfplot(y='tip', data=tips)
plt.axvline(0.5, c="black")

# %%
tips.tip.median()
# Out:
# 2.9

# %%
sns.ecdfplot(x='tip', data=tips, hue='time')
# Out:
# <AxesSubplot:xlabel='tip', ylabel='Proportion'>

# %%
sns.ecdfplot(x='tip', data=tips, hue='day')
# Out:
# <AxesSubplot:xlabel='tip', ylabel='Proportion'>

# %%
sns.ecdfplot(x='tip', data=tips, hue='day', stat='count')
# Out:
# <AxesSubplot:xlabel='tip', ylabel='Count'>

# %%
sns.ecdfplot(x='tip', data=tips, complementary=True, stat='count')
# Out:
# <AxesSubplot:xlabel='tip', ylabel='Count'>

# %%
sns.ecdfplot(x='tip', data=tips, weights='tip')
plt.axhline(0.5, c="black")

# %%
sns.ecdfplot(x='tip', data=tips, hue='day',palette='summer', lw=3)
# Out:
# <AxesSubplot:xlabel='tip', ylabel='Proportion'>

# %%
p = sns.ecdfplot(x='tip', data=tips, hue='day',palette='summer', lw=3)
p.legend(['Thursday', 'Friday', 'Saturday', 'Sunday'], title='Day of week', loc=4)

# %% [markdown]
# ## BoxPlot

# %%
cars
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %%
sns.set_style('whitegrid')

# %%
cars2 = cars[cars.cylinders.isin([4,6,8])]

# %%
sns.boxplot(x='mpg', data=cars2)
# Out:
# <AxesSubplot:xlabel='mpg'>

# %%
cars2.mpg.describe()
# Out:
# count    385.000000
# mean      23.445455
# std        7.836911
# min        9.000000
# 25%       17.000000
# 50%       23.000000
# 75%       29.000000
# max       46.600000
# Name: mpg, dtype: float64

# %%
sns.boxplot(x='origin', y='mpg', data=cars2)
# Out:
# <AxesSubplot:xlabel='origin', ylabel='mpg'>

# %%
sns.boxplot(x='origin', y='mpg', data=cars2, hue='cylinders')
# Out:
# <AxesSubplot:xlabel='origin', ylabel='mpg'>

# %%
cars2.model_year.describe()
# Out:
# count    385.000000
# mean      75.961039
# std        3.692058
# min       70.000000
# 25%       73.000000
# 50%       76.000000
# 75%       79.000000
# max       82.000000
# Name: model_year, dtype: float64

# %%
cars2['newer_model'] = cars2.model_year > 76
# Out:
# C:\Users\sinch\AppData\Local\Temp\ipykernel_6376\2570501904.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cars2['newer_model'] = cars2.model_year > 76

# %%
sns.boxplot(x='origin', y='mpg', data=cars2, hue='newer_model')
# Out:
# <AxesSubplot:xlabel='origin', ylabel='mpg'>

# %%
sns.boxplot(y='origin', x='mpg', data=cars2)
# Out:
# <AxesSubplot:xlabel='mpg', ylabel='origin'>

# %%
sns.boxplot(y='origin', x='mpg', data=cars2, order=['japan', 'europe', 'usa'])
# Out:
# <AxesSubplot:xlabel='mpg', ylabel='origin'>

# %%
sns.boxplot(y='origin', x='mpg', data=cars2, order=['japan', 'europe', 'usa'], hue='newer_model', hue_order=[True, False])
# Out:
# <AxesSubplot:xlabel='mpg', ylabel='origin'>

# %%
sns.boxplot(y='origin', x='mpg', data=cars2, color='g')
# Out:
# <AxesSubplot:xlabel='mpg', ylabel='origin'>

# %%
sns.boxplot(y='origin', x='mpg', data=cars2, order=['japan', 'europe', 'usa'], color='g', hue='newer_model')
# Out:
# <AxesSubplot:xlabel='mpg', ylabel='origin'>

# %%
sns.boxplot(y='origin', x='mpg', data=cars2, width=0.5)
# Out:
# <AxesSubplot:xlabel='mpg', ylabel='origin'>

# %%
sns.boxplot(y='origin', x='mpg', data=cars2, linewidth=2.5)
# Out:
# <AxesSubplot:xlabel='mpg', ylabel='origin'>

# %%
sns.boxplot(y='origin', x='mpg', data=cars2, whis=1)
# Out:
# <AxesSubplot:xlabel='mpg', ylabel='origin'>

# %%
sns.boxplot(y='origin', x='mpg', data=cars2, fliersize=10)
# Out:
# <AxesSubplot:xlabel='mpg', ylabel='origin'>

# %%
sns.boxplot(y='origin', x='mpg', data=cars2, showcaps=False)
# Out:
# <AxesSubplot:xlabel='mpg', ylabel='origin'>

# %% [markdown]
# ## ViolinPlot

# %%
sns.violinplot(data=cars2, x='displacement')
# Out:
# <AxesSubplot:xlabel='displacement'>

# %%
sns.violinplot(data=cars2, x='cylinders', y='displacement')
# Out:
# <AxesSubplot:xlabel='cylinders', ylabel='displacement'>

# %%
sns.violinplot(data=cars2, x='cylinders', y='displacement', hue='origin')
# Out:
# <AxesSubplot:xlabel='cylinders', ylabel='displacement'>

# %% [markdown]
# ### Violinplot: Options

# %%
sns.violinplot(data=cars2[cars2.origin.isin(['japan', 'europe'])], x='cylinders', y='displacement', hue='origin')
plt.legend(loc=2)

# %%
sns.violinplot(data=cars2[cars2.origin.isin(['japan', 'europe'])], x='cylinders', y='displacement', hue='origin', split=True)
plt.legend(loc=2)

# %%
sns.violinplot(data=cars2[cars2.origin.isin(['japan', 'europe'])],
               x='cylinders', y='displacement', hue='origin',
              split=True, inner='quartiles')
plt.legend(loc=2)

# %%
sns.violinplot(data=cars2[cars2.origin.isin(['japan', 'europe'])],
               x='cylinders', y='displacement', hue='origin',
              split=True, scale='count')
plt.legend(loc=2)

# %%
sns.violinplot(data=cars2[cars2.origin.isin(['japan', 'europe'])],
               x='cylinders', y='displacement', hue='origin',
              split=True, scale='count', scale_hue=False)
plt.legend(loc=2)

# %% [markdown]
# ### Violinplot: Styling

# %%
sns.violinplot(data=cars2, order=['japan', 'europe', 'usa'],
               x='origin', y='displacement')
# Out:
# <AxesSubplot:xlabel='origin', ylabel='displacement'>

# %%
sns.violinplot(data=cars2, linewidth=3,
               x='origin', y='displacement')
# Out:
# <AxesSubplot:xlabel='origin', ylabel='displacement'>

# %%
sns.violinplot(data=cars2, bw=0.3,
               x='cylinders', y='displacement')
# Out:
# <AxesSubplot:xlabel='cylinders', ylabel='displacement'>

# %% [markdown]
# ## SwarmPlot

# %%
sns.swarmplot(data=cars, x='horsepower')
# Out:
# <AxesSubplot:xlabel='horsepower'>

# %%
sns.swarmplot(data=cars, x='origin', y='horsepower')
# Out:
# C:\Python310\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 11.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='origin', ylabel='horsepower'>

# %%
sns.swarmplot(data=cars2, x='origin', y='horsepower', hue='cylinders')
# Out:
# C:\Python310\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 11.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='origin', ylabel='horsepower'>

# %%
sns.swarmplot(data=cars2, x='origin', y='horsepower', hue='cylinders', dodge=True)
# Out:
# C:\Python310\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 43.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Python310\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 46.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Python310\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 28.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Python310\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 24.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='origin', ylabel='horsepower'>

# %% [markdown]
# ### SwarmPlot: overlay

# %%
usa = cars2[cars.origin=='usa']
# Out:
# C:\Users\sinch\AppData\Local\Temp\ipykernel_6376\2268619594.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   usa = cars2[cars.origin=='usa']

# %%
sns.boxplot(data=usa, x='cylinders', y='horsepower')
sns.swarmplot(data=usa, x='cylinders', y='horsepower')
# Out:
# C:\Python310\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 8.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='cylinders', ylabel='horsepower'>

# %%
sns.boxplot(data=usa, x='cylinders', y='horsepower')
sns.swarmplot(data=usa, x='cylinders', y='horsepower', color='k', alpha=0.5)
# Out:
# C:\Python310\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 8.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='cylinders', ylabel='horsepower'>

# %%
sns.boxplot(data=usa, x='cylinders', y='horsepower', whis=np.inf)
sns.swarmplot(data=usa, x='cylinders', y='horsepower', color='k', alpha=0.5)
# Out:
# C:\Python310\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 8.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='cylinders', ylabel='horsepower'>

# %%
sns.violinplot(data=usa, x='cylinders', y='horsepower', scale='width')
sns.swarmplot(data=usa, x='cylinders', y='horsepower', size=4, color='w', alpha=0.5)
# Out:
# <AxesSubplot:xlabel='cylinders', ylabel='horsepower'>

# %%
sns.violinplot(data=usa, x='cylinders', y='horsepower', scale='width', inner=None, color='xkcd:forest green')
sns.swarmplot(data=usa, x='cylinders', y='horsepower', size=3, color='w', alpha=0.5)
# Out:
# <AxesSubplot:xlabel='cylinders', ylabel='horsepower'>

# %% [markdown]
# ### Swarmplot: Styling

# %%
sns.swarmplot(data=cars, x='horsepower', linewidth=1)
# Out:
# <AxesSubplot:xlabel='horsepower'>

# %%
sns.swarmplot(data=cars, x='horsepower', linewidth=1, edgecolor='k')
# Out:
# <AxesSubplot:xlabel='horsepower'>

# %%
plt.figure(figsize=(8,4))
sns.swarmplot(data=cars2, x='horsepower', marker='*')
# Out:
# <AxesSubplot:xlabel='horsepower'>

# %% [markdown]
# ## Stripplot

# %%
sns.stripplot(data=cars, x='weight')
# Out:
# <AxesSubplot:xlabel='weight'>

# %%
sns.stripplot(data=cars2, x='weight', y='origin')
# Out:
# <AxesSubplot:xlabel='weight', ylabel='origin'>

# %%
sns.stripplot(data=cars2, x='weight', y='origin',
             hue='cylinders')
# Out:
# <AxesSubplot:xlabel='weight', ylabel='origin'>

# %%
sns.stripplot(data=cars2, x='weight', y='origin',
             hue='cylinders', dodge=True)
# Out:
# <AxesSubplot:xlabel='weight', ylabel='origin'>

# %%
sns.stripplot(data=cars2, x='origin', y='weight',
             hue='cylinders')
# Out:
# <AxesSubplot:xlabel='origin', ylabel='weight'>

# %% [markdown]
# ### Stripplot: Styling

# %%
sns.stripplot(data=cars2, x='weight', y='origin', jitter=False)
# Out:
# <AxesSubplot:xlabel='weight', ylabel='origin'>

# %%
sns.stripplot(data=cars2, x='weight', y='origin', jitter=0.05)
# Out:
# <AxesSubplot:xlabel='weight', ylabel='origin'>

# %%
import ipywidgets as wiz

def jitter_widget(j=0.1):
    sns.stripplot(data=cars2, x='weight', y='origin', jitter=j)

# %%
wiz.interactive(jitter_widget, j=(0, 0.65, 0.05))
# Out:
# interactive(children=(FloatSlider(value=0.1, description='j', max=0.65, step=0.05), Output()), _dom_classes=('…

# %%
sns.stripplot(data=cars2, x='weight', y='origin', alpha=0.5)
# Out:
# <AxesSubplot:xlabel='weight', ylabel='origin'>

# %%
sns.stripplot(data=cars2, x='weight', y='origin', alpha=0.3, size=8)
# Out:
# <AxesSubplot:xlabel='weight', ylabel='origin'>

# %%
sns.stripplot(data=cars2, x='weight', y='origin', linewidth=1)
# Out:
# <AxesSubplot:xlabel='weight', ylabel='origin'>

# %%
sns.stripplot(data=cars2, x='weight', y='origin', linewidth=1, edgecolor='k')
# Out:
# <AxesSubplot:xlabel='weight', ylabel='origin'>

# %%
sns.stripplot(data=cars2, x='weight', y='origin', alpha=0.7, size=10, jitter=0.25, marker='*')
# Out:
# <AxesSubplot:xlabel='weight', ylabel='origin'>

# %% [markdown]
# ## LinePlot

# %%
df = pd.read_csv('dataset.csv', parse_dates=[3])

# %%
df
# Out:
#       SystemCodeNumber  Capacity  Occupancy         LastUpdated
# 0          BHMBCCMKT01       577         61 2016-10-04 07:59:42
# 1          BHMBCCMKT01       577         64 2016-10-04 08:25:42
# 2          BHMBCCMKT01       577         80 2016-10-04 08:59:42
# 3          BHMBCCMKT01       577        107 2016-10-04 09:32:46
# 4          BHMBCCMKT01       577        150 2016-10-04 09:59:48
# ...                ...       ...        ...                 ...
# 35712         Shopping      1920       1517 2016-12-19 14:30:33
# 35713         Shopping      1920       1487 2016-12-19 15:03:34
# 35714         Shopping      1920       1432 2016-12-19 15:29:33
# 35715         Shopping      1920       1321 2016-12-19 16:03:35
# 35716         Shopping      1920       1180 2016-12-19 16:30:35
#
# [35717 rows x 4 columns]

# %%
df2 = df.rename(columns={'SystemCodeNumber': 'Location', 'LastUpdated': 'Timestamp'})

# %%
df2
# Out:
#           Location  Capacity  Occupancy           Timestamp
# 0      BHMBCCMKT01       577         61 2016-10-04 07:59:42
# 1      BHMBCCMKT01       577         64 2016-10-04 08:25:42
# 2      BHMBCCMKT01       577         80 2016-10-04 08:59:42
# 3      BHMBCCMKT01       577        107 2016-10-04 09:32:46
# 4      BHMBCCMKT01       577        150 2016-10-04 09:59:48
# ...            ...       ...        ...                 ...
# 35712     Shopping      1920       1517 2016-12-19 14:30:33
# 35713     Shopping      1920       1487 2016-12-19 15:03:34
# 35714     Shopping      1920       1432 2016-12-19 15:29:33
# 35715     Shopping      1920       1321 2016-12-19 16:03:35
# 35716     Shopping      1920       1180 2016-12-19 16:30:35
#
# [35717 rows x 4 columns]

# %%
df2['Day'] = df2['Timestamp'].dt.date
df2['Month'] = df2['Timestamp'].dt.month
df2['Hour'] = df2['Timestamp'].dt.hour

# %%
df2
# Out:
#           Location  Capacity  Occupancy           Timestamp         Day  \
# 0      BHMBCCMKT01       577         61 2016-10-04 07:59:42  2016-10-04
# 1      BHMBCCMKT01       577         64 2016-10-04 08:25:42  2016-10-04
# 2      BHMBCCMKT01       577         80 2016-10-04 08:59:42  2016-10-04
# 3      BHMBCCMKT01       577        107 2016-10-04 09:32:46  2016-10-04
# 4      BHMBCCMKT01       577        150 2016-10-04 09:59:48  2016-10-04
# ...            ...       ...        ...                 ...         ...
# 35712     Shopping      1920       1517 2016-12-19 14:30:33  2016-12-19
# 35713     Shopping      1920       1487 2016-12-19 15:03:34  2016-12-19
# 35714     Shopping      1920       1432 2016-12-19 15:29:33  2016-12-19
# 35715     Shopping      1920       1321 2016-12-19 16:03:35  2016-12-19
# 35716     Shopping      1920       1180 2016-12-19 16:30:35  2016-12-19
#
#        Month  Hour
# 0         10     7
# 1         10     8
# 2         10     8
# 3         10     9
# ...

# %%
park = df2[df2.Location.isin(['Broad Street', 'NIA South'])]
park
# Out:
#            Location  Capacity  Occupancy           Timestamp         Day  \
# 20171  Broad Street       690        178 2016-10-04 07:59:42  2016-10-04
# 20172  Broad Street       690        269 2016-10-04 08:25:42  2016-10-04
# 20173  Broad Street       690        415 2016-10-04 08:59:42  2016-10-04
# 20174  Broad Street       690        530 2016-10-04 09:32:46  2016-10-04
# 20175  Broad Street       690        600 2016-10-04 09:59:48  2016-10-04
# ...             ...       ...        ...                 ...         ...
# 25234     NIA South       788        147 2016-12-16 14:30:10  2016-12-16
# 25235     NIA South       788        153 2016-12-16 14:56:11  2016-12-16
# 25236     NIA South       788        159 2016-12-16 15:30:10  2016-12-16
# 25237     NIA South       788        160 2016-12-16 16:03:11  2016-12-16
# 25238     NIA South       788        164 2016-12-16 16:30:12  2016-12-16
#
#        Month  Hour
# 20171     10     7
# 20172     10     8
# 20173     10     8
# ...

# %%
park.Location.unique()
# Out:
# array(['Broad Street', 'NIA South'], dtype=object)

# %%
sns.set_style('dark')

# %%
months = [pd.datetime(2016, 10, 1),
         pd.datetime(2016, 11, 1),
         pd.datetime(2016, 12, 1)]
plt.rc('date.autoformatter', day='%b %Y')
# Out:
# C:\Users\sinch\AppData\Local\Temp\ipykernel_6376\2100103840.py:1: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   months = [pd.datetime(2016, 10, 1),
# C:\Users\sinch\AppData\Local\Temp\ipykernel_6376\2100103840.py:2: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   pd.datetime(2016, 11, 1),
# C:\Users\sinch\AppData\Local\Temp\ipykernel_6376\2100103840.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   pd.datetime(2016, 12, 1)]

# %%
sns.lineplot(data=park, x='Day', y='Occupancy')
plt.xticks(months)
# Out:
# ([<matplotlib.axis.XTick at 0x26df0935cf0>,
# ...
#  [Text(0, 0, ''), Text(0, 0, ''), Text(0, 0, '')])

# %%
sns.lineplot(data=park, x='Hour', y='Occupancy')
# Out:
# <AxesSubplot:xlabel='Hour', ylabel='Occupancy'>

# %%
sns.lineplot(data=park, x='Hour', y='Occupancy', n_boot=10)
# Out:
# <AxesSubplot:xlabel='Hour', ylabel='Occupancy'>

# %%
sns.lineplot(data=park, x='Hour', y='Occupancy', ci=69)
# Out:
# <AxesSubplot:xlabel='Hour', ylabel='Occupancy'>

# %%
sns.lineplot(data=park, x='Hour', y='Occupancy', ci=None)
# Out:
# <AxesSubplot:xlabel='Hour', ylabel='Occupancy'>

# %%
sns.lineplot(data=park, x='Hour', y='Occupancy', estimator='sum')
# Out:
# <AxesSubplot:xlabel='Hour', ylabel='Occupancy'>

# %%
sns.lineplot(data=park, x='Hour', y='Occupancy', estimator='std')
# Out:
# <AxesSubplot:xlabel='Hour', ylabel='Occupancy'>

# %%
sns.lineplot(data=park, x='Day', y='Occupancy', hue='Location')
# Out:
# <AxesSubplot:xlabel='Day', ylabel='Occupancy'>

# %%
sns.lineplot(data=park, x='Day', y='Occupancy', hue='Location', palette=['gray', 'xkcd:brick red'])
plt.xticks(months)
# Out:
# ([<matplotlib.axis.XTick at 0x26df0da0a90>,
# ...
#  [Text(0, 0, ''), Text(0, 0, ''), Text(0, 0, '')])

# %%
sns.lineplot(data=park, x='Day', y='Occupancy', style='Location')
# Out:
# <AxesSubplot:xlabel='Day', ylabel='Occupancy'>

# %%
sns.lineplot(data=park, x='Day', y='Occupancy', hue='Location', style='Location')
# Out:
# <AxesSubplot:xlabel='Day', ylabel='Occupancy'>

# %%
sns.lineplot(data=park, x='Hour', y='Occupancy', size='Location')
# Out:
# <AxesSubplot:xlabel='Hour', ylabel='Occupancy'>

# %%
sns.lineplot(data=park, x='Hour', y='Occupancy', size='Month', ci=None)
# Out:
# <AxesSubplot:xlabel='Hour', ylabel='Occupancy'>

# %%
sns.lineplot(data=park, x='Day', y='Occupancy', ci=None, lw=4, color='#aa00aa', alpha=0.5)
plt.xticks(months);

# %% [markdown]
# ## RegPlot

# %%
diamonds = sns.load_dataset("diamonds")
diamonds
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
diamonds2 = diamonds.sample(n=200, random_state=44)
diamonds2
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 40423   0.70       Good     F      I1   63.8   60.0   1134  5.64  5.45  3.54
# 16309   1.11    Premium     H     VS2   61.1   59.0   6527  6.66  6.63  4.06
# 3260    0.93       Fair     G     SI1   64.4   57.0   3358  6.14  6.09  3.94
# 36811   0.30    Premium     G      IF   62.9   58.0    956  4.25  4.21  2.66
# 48721   0.52      Ideal     G    VVS2   60.8   57.0   2012  5.21  5.16  3.15
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 36480   0.43  Very Good     G     VS1   60.9   57.0    943  4.88  4.91  2.98
# 255     1.05       Fair     J     SI2   65.8   59.0   2789  6.41  6.27  4.18
# 46767   0.52      Ideal     D     VS2   60.3   56.0   1802  5.27  5.24  3.17
# 52409   0.71      Ideal     E     SI2   65.5   55.0   2511  5.62  5.56  3.66
# 35862   0.43      Ideal     G     SI1   61.3   55.0    917  4.88  4.90  3.00
#
# [200 rows x 10 columns]

# %%
sns.set_style('dark')

# %%
sns.regplot(x='carat', y='price', data=diamonds2)
# Out:
# <AxesSubplot:xlabel='carat', ylabel='price'>

# %%
sns.regplot(x='carat', y='price', data=diamonds2, fit_reg=False)
# Out:
# <AxesSubplot:xlabel='carat', ylabel='price'>

# %%
sns.regplot(x='carat', y='price', data=diamonds2, scatter=False)
# Out:
# <AxesSubplot:xlabel='carat', ylabel='price'>

# %%
sns.regplot(x='carat', y='price', data=diamonds2, ci=None)
# Out:
# <AxesSubplot:xlabel='carat', ylabel='price'>

# %%
cut_map = {
    'Fair': 1,
    'Good': 2,
    'Very Good': 3,
    'Premium': 4,
    'Ideal': 5
}

# %%
diamonds2['cut_value'] = diamonds2.cut.map(cut_map)

# %%
diamonds2['cut_value'] = diamonds2['cut_value'].cat.as_ordered()

# %%
diamonds2.cut_value.astype(int)
# Out:
# 40423    2
# 16309    4
# 3260     1
# 36811    4
# 48721    5
#         ..
# 36480    3
# 255      1
# 46767    5
# 52409    5
# 35862    5
# Name: cut_value, Length: 200, dtype: int32

# %%
sns.regplot(x='cut_value', y='price', data=diamonds2)
# Out:
# <AxesSubplot:xlabel='cut_value', ylabel='price'>

# %%
sns.regplot(x='cut_value', y='price', data=diamonds2, x_estimator=np.mean)
# Out:
# <AxesSubplot:xlabel='cut_value', ylabel='price'>

# %%
sns.regplot(x='carat', y='price', data=diamonds2, order=2)
# Out:
# <AxesSubplot:xlabel='carat', ylabel='price'>

# %% [markdown]
# ### RegPlot: Styling

# %%
sns.regplot(x='carat', y='price', data=diamonds2, marker='d')
# Out:
# <AxesSubplot:xlabel='carat', ylabel='price'>

# %%
sns.regplot(x='carat', y='price', data=diamonds2, scatter_kws={'s':100, 'alpha':0.5, 'color': 'gray'})
# Out:
# <AxesSubplot:xlabel='carat', ylabel='price'>

# %%
sns.regplot(x='carat', y='price', data=diamonds2, ci=None, line_kws={'lw':4, 'linestyle':'-.', 'color': 'green'})
# Out:
# <AxesSubplot:xlabel='carat', ylabel='price'>

# %% [markdown]
# ## ScatterPlot: is a Relational plot

# %%
diamonds = sns.load_dataset("diamonds")
diamonds
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
diamonds2 = diamonds.loc[diamonds['cut'].isin(['Premium', 'Good']) & diamonds['color'].isin(['D', 'F', 'J'])]
diamonds3 = diamonds2.sample(n=100, random_state=22)

# %%
diamonds3['cut'].astype(str)
# Out:
# 10801    Premium
# 3457     Premium
# 21628    Premium
# 3918     Premium
# 46240    Premium
#           ...
# 48743       Good
# 23171    Premium
# 39946       Good
# 7940     Premium
# 9934     Premium
# Name: cut, Length: 100, dtype: object

# %%
diamonds3.color.astype(str)
# Out:
# 10801    F
# 3457     D
# 21628    D
# 3918     J
# 46240    F
#         ..
# 48743    J
# 23171    J
# 39946    F
# 7940     F
# 9934     D
# Name: color, Length: 100, dtype: object

# %%
sns.set_style('dark')

# %%
sns.scatterplot(x='carat', y='price', data=diamonds3)
# Out:
# <AxesSubplot:xlabel='carat', ylabel='price'>

# %%
sns.scatterplot(x='x', y='y', data=diamonds3)
# Out:
# <AxesSubplot:xlabel='x', ylabel='y'>

# %%
sns.scatterplot(x='carat', y='price', data=diamonds3, hue='cut')
# Out:
# <AxesSubplot:xlabel='carat', ylabel='price'>

# %%
sns.scatterplot(x='carat', y='price', data=diamonds3, hue='depth')
# Out:
# <AxesSubplot:xlabel='carat', ylabel='price'>

# %%
sns.scatterplot(x='carat', y='price', data=diamonds3, s=100)
# Out:
# <AxesSubplot:xlabel='carat', ylabel='price'>

# %%
sns.scatterplot(x='carat', y='price', data=diamonds3, s=100, style='cut')
# Out:
# <AxesSubplot:xlabel='carat', ylabel='price'>

# %%
sns.scatterplot(x='carat', y='price', data=diamonds3, size='cut')
# Out:
# <AxesSubplot:xlabel='carat', ylabel='price'>

# %%
sns.scatterplot(x='carat', y='price', data=diamonds3, size='depth')
# Out:
# <AxesSubplot:xlabel='carat', ylabel='price'>

# %%
sns.scatterplot(x='carat', y='price', data=diamonds3, hue='cut', s=100, style='cut')
# Out:
# <AxesSubplot:xlabel='carat', ylabel='price'>

# %%
sns.scatterplot(x='carat', y='price', data=diamonds3, hue='cut', s=100, style='color')
# Out:
# <AxesSubplot:xlabel='carat', ylabel='price'>

# %%
sns.scatterplot(x='carat', y='price', data=diamonds3, hue='cut', s=100, alpha=0.6)
# Out:
# <AxesSubplot:xlabel='carat', ylabel='price'>

# %%
sns.scatterplot(x='carat', y='price', data=diamonds3, s=200, marker='*', edgecolor='black')
# Out:
# <AxesSubplot:xlabel='carat', ylabel='price'>

# %% [markdown]
# ## Heatmap

# %%
cars
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %%
cars.groupby('origin').cylinders.value_counts()
# Out:
# origin  cylinders
# europe  4             61
#         6              4
#         5              3
# japan   4             69
#         6              6
#         3              4
# usa     8            103
#         6             73
#         4             69
# Name: cylinders, dtype: int64

# %%
cars.groupby('origin').cylinders.value_counts().unstack()
# Out:
# cylinders    3     4    5     6      8
# origin
# europe     NaN  61.0  3.0   4.0    NaN
# japan      4.0  69.0  NaN   6.0    NaN
# usa        NaN  69.0  NaN  73.0  103.0

# %%
origin_cyl = cars.groupby('origin').cylinders.value_counts().unstack().fillna(0)
origin_cyl
# Out:
# cylinders    3     4    5     6      8
# origin
# europe     0.0  61.0  3.0   4.0    0.0
# japan      4.0  69.0  0.0   6.0    0.0
# usa        0.0  69.0  0.0  73.0  103.0

# %%
sns.heatmap(origin_cyl)
# Out:
# <AxesSubplot:xlabel='cylinders', ylabel='origin'>

# %%
sns.heatmap(origin_cyl.T)
# Out:
# <AxesSubplot:xlabel='origin', ylabel='cylinders'>

# %%
cars.corr()
# Out:
#                    mpg  cylinders  displacement  horsepower    weight  \
# mpg           1.000000  -0.777618     -0.805127   -0.778427 -0.832244
# cylinders    -0.777618   1.000000      0.950823    0.842983  0.897527
# displacement -0.805127   0.950823      1.000000    0.897257  0.932994
# horsepower   -0.778427   0.842983      0.897257    1.000000  0.864538
# weight       -0.832244   0.897527      0.932994    0.864538  1.000000
# acceleration  0.423329  -0.504683     -0.543800   -0.689196 -0.416839
# model_year    0.580541  -0.345647     -0.369855   -0.416361 -0.309120
#
#               acceleration  model_year
# mpg               0.423329    0.580541
# cylinders        -0.504683   -0.345647
# displacement     -0.543800   -0.369855
# horsepower       -0.689196   -0.416361
# weight           -0.416839   -0.309120
# acceleration      1.000000    0.290316
# model_year        0.290316    1.000000

# %%
sns.heatmap(cars.corr())
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(origin_cyl, cmap="Blues")
# Out:
# <AxesSubplot:xlabel='cylinders', ylabel='origin'>

# %%
sns.heatmap(cars.corr(), cmap='RdBu')
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(cars.corr(), cmap='RdBu', center=0)
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(cars.corr(), cmap='RdBu', vmin=-1, vmax=1)
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(origin_cyl, cmap="Blues", annot=True)
# Out:
# <AxesSubplot:xlabel='cylinders', ylabel='origin'>

# %%
sns.heatmap(origin_cyl, cmap="Blues", annot=True, fmt=".0f")
# Out:
# <AxesSubplot:xlabel='cylinders', ylabel='origin'>

# %%
sns.heatmap(origin_cyl, cmap="Blues", annot=True, fmt=".0f",
            annot_kws={
                'fontsize': 16, 
                'fontweight':'bold', 
                'fontfamily':'serif',
                #'color':'black'
            }
           )
# Out:
# <AxesSubplot:xlabel='cylinders', ylabel='origin'>

# %%
sns.heatmap(cars.corr(), cmap='RdBu', linewidths=1)
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(cars.corr(), cmap='RdBu', linewidths=1, linecolor='black')
# Out:
# <AxesSubplot:>

# %%
labels = ['MPG', 'Cylinders', 'Displacement', 'Horsepower',
          'Weight', 'Acceleration', 'Model Year']

# %%
sns.heatmap(cars.corr(), cmap='RdBu', linewidths=1, linecolor='black', xticklabels=labels, yticklabels=labels)
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(cars.corr(), cmap='RdBu', linewidths=1, linecolor='black', xticklabels=False, yticklabels=labels)
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(cars.corr(), cmap='RdBu', linewidths=1, linecolor='black', xticklabels=labels, yticklabels=labels, 
           square=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Clustermap

# %%
toy_data_dict = {
    'name': ['andy', 'ben', 'claire', 'david'],
    'hours_studied': [10, 20, 12, 28],
    'score': [15, 20, 16, 25],
    'address': [11, 24, 18, 9]
}

# %%
toy_data = pd.DataFrame(toy_data_dict)
toy_data.set_index('name', inplace=True)
toy_data
# Out:
#         hours_studied  score  address
# name
# andy               10     15       11
# ben                20     20       24
# claire             12     16       18
# david              28     25        9

# %%
sns.clustermap(toy_data, figsize=(4,4), annot=True)

# %%
penguins = sns.load_dataset('penguins')
penguins
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
num_cols = penguins.columns[2:6]
num_cols
# Out:
# Index(['bill_length_mm', 'bill_depth_mm', 'flipper_length_mm', 'body_mass_g'], dtype='object')

# %% [markdown]
# ## Barplot

# %%
sns.set_style('darkgrid')

# %%
sns.barplot(x='species', y='body_mass_g', data=penguins)
# Out:
# <AxesSubplot:xlabel='species', ylabel='body_mass_g'>

# %%
penguins.groupby('species').body_mass_g.mean()
# Out:
# species
# Adelie       3700.662252
# Chinstrap    3733.088235
# Gentoo       5076.016260
# Name: body_mass_g, dtype: float64

# %%
sns.barplot(y='species', x='body_mass_g', data=penguins)
# Out:
# <AxesSubplot:xlabel='body_mass_g', ylabel='species'>

# %%
sns.barplot(x='species', y='body_mass_g', data=penguins, ci=95)
# Out:
# <AxesSubplot:xlabel='species', ylabel='body_mass_g'>

# %%
sns.barplot(x='species', y='body_mass_g', data=penguins, ci=69)
# Out:
# <AxesSubplot:xlabel='species', ylabel='body_mass_g'>

# %%
sns.barplot(x='species', y='body_mass_g', data=penguins, ci=None)
# Out:
# <AxesSubplot:xlabel='species', ylabel='body_mass_g'>

# %%
sns.barplot(x='species', y='body_mass_g', data=penguins, estimator=np.std)
# Out:
# <AxesSubplot:xlabel='species', ylabel='body_mass_g'>

# %%
penguins.groupby('species').body_mass_g.describe()
# Out:
#            count         mean         std     min     25%     50%     75%  \
# species
# Adelie     151.0  3700.662252  458.566126  2850.0  3350.0  3700.0  4000.0
# Chinstrap   68.0  3733.088235  384.335081  2700.0  3487.5  3700.0  3950.0
# Gentoo     123.0  5076.016260  504.116237  3950.0  4700.0  5000.0  5500.0
#
#               max
# species
# Adelie     4775.0
# Chinstrap  4800.0
# Gentoo     6300.0

# %%
sns.barplot(x='species', y='body_mass_g', data=penguins, estimator=np.max)
# Out:
# <AxesSubplot:xlabel='species', ylabel='body_mass_g'>

# %%
sns.barplot(x='species', y='body_mass_g', data=penguins, hue='sex')
# Out:
# <AxesSubplot:xlabel='species', ylabel='body_mass_g'>

# %%
sns.barplot(x='species', y='body_mass_g', data=penguins, hue='sex',
            order=['Gentoo', 'Chinstrap', 'Adelie'],
           hue_order=['Female', 'Male'])
# Out:
# <AxesSubplot:xlabel='species', ylabel='body_mass_g'>

# %%
sns.barplot(x='species', y='body_mass_g', data=penguins, color='c',
            errcolor='m', errwidth=8)
# Out:
# <AxesSubplot:xlabel='species', ylabel='body_mass_g'>

# %%
sns.barplot(x='species', y='body_mass_g', data=penguins,
           palette='hot')
# Out:
# <AxesSubplot:xlabel='species', ylabel='body_mass_g'>

# %%
sns.barplot(x='species', y='body_mass_g', data=penguins, ci=None,
            color='aliceblue', edgecolor='mediumblue', lw=3)
# Out:
# <AxesSubplot:xlabel='species', ylabel='body_mass_g'>

# %% [markdown]
# ## Countplot

# %%
diamonds2 = diamonds[diamonds.clarity.isin(['SI1', 'VS2'])]

# %%
diamonds2.shape
# Out:
# (25323, 10)

# %%
sns.set_style('darkgrid')

# %%
sns.countplot(data=diamonds2, x='color')
# Out:
# <AxesSubplot:xlabel='color', ylabel='count'>

# %%
diamonds2.color.value_counts()
# Out:
# E    4896
# F    4332
# G    4323
# H    3918
# D    3780
# I    2593
# J    1481
# Name: color, dtype: int64

# %%
sns.countplot(data=diamonds2, y='color')
# Out:
# <AxesSubplot:xlabel='count', ylabel='color'>

# %%
sns.countplot(data=diamonds2, x='cut', )
# Out:
# <AxesSubplot:xlabel='cut', ylabel='count'>

# %%
sns.countplot(data=diamonds2, x='clarity')
# Out:
# <AxesSubplot:xlabel='clarity', ylabel='count'>

# %%
color_order = ['J', 'I', 'H', 'G', 'F', 'E', 'D']
sns.countplot(x='color', data=diamonds2, order=color_order)
# Out:
# <AxesSubplot:xlabel='color', ylabel='count'>

# %%
diamonds2.color.value_counts().index
# Out:
# CategoricalIndex(['E', 'F', 'G', 'H', 'D', 'I', 'J'], categories=['D', 'E', 'F', 'G', 'H', 'I', 'J'], ordered=False, dtype='category')

# %%
sns.countplot(x='color', data=diamonds2, order=diamonds2.color.value_counts().index)
# Out:
# <AxesSubplot:xlabel='color', ylabel='count'>

# %%
sns.countplot(x='color', data=diamonds2, order=diamonds2.color.value_counts().index[::-1])
# Out:
# <AxesSubplot:xlabel='color', ylabel='count'>

# %%
sns.countplot(x='color', data=diamonds2, hue='clarity', hue_order=['SI1', 'VS2'])
# Out:
# <AxesSubplot:xlabel='color', ylabel='count'>

# %%
sns.countplot(x='color', data=diamonds2, color='skyblue')
# Out:
# <AxesSubplot:xlabel='color', ylabel='count'>

# %%
sns.countplot(x='color', data=diamonds2, palette='twilight')
# Out:
# <AxesSubplot:xlabel='color', ylabel='count'>

# %%
sns.countplot(x='color', data=diamonds2, lw=4, ec='k', hatch='\/')
# Out:
# <AxesSubplot:xlabel='color', ylabel='count'>
